# %% [markdown]
# <a href="https://colab.research.google.com/github/Mmarshy/testing-/blob/main/Q1_Narra_FA1_Maglimolo_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
X1 =int(input(str("what is your X1?: ")))
X2 =int(input(str("what is your X2?: ")))
Y1 =int(input(str("what is your Y1?: ")))
Y2 =int(input(str("what is your Y2?: ")))

distance = math.sqrt(pow(X1-X2 , 2) + pow(Y1-Y2 , 2))
print("the distance between your coordinates is")
print(distance)

#it is mopre practical in using libraries than making it from scratch because libraries already have the code and is just waiting for you to use it but if you make it from scratch it take you longer be cause you still have to make it than use an existing code
# Out:
# what is your X1?: 3
# what is your X2?: 4
# what is your Y1?: 5
# what is your Y2?: 6
# the distance between your coordinates is
# 1.4142135623730951
